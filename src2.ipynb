# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
weights = np.random.normal(loc=65,scale=5,size=280)

# %%
weights
# Out:
# array([58.33617084, 61.41976843, 66.55401725, 63.20652422, 64.43209042,
#        67.73557368, 64.89268977, 56.99471994, 63.71877008, 66.00700965,
#        56.11074458, 62.85329962, 73.35047532, 65.02389706, 67.91004283,
#        64.4729299 , 67.6869028 , 64.12806475, 64.83965374, 69.95301707,
#        74.86992992, 60.52278253, 67.43852683, 70.29508887, 60.6325547 ,
#        60.83927169, 71.75504742, 66.7476541 , 66.42038742, 58.44277727,
#        73.60807649, 54.2897176 , 63.37892076, 74.9655217 , 58.77502516,
#        69.70158893, 64.78043572, 69.72458557, 70.41062451, 71.1980498 ,
#        70.29044108, 65.95007184, 64.23637937, 67.07395863, 67.0511719 ,
#        71.27367272, 60.49850889, 59.61516252, 68.45630421, 69.64200356,
#        60.13810044, 66.14331494, 61.04629593, 71.59813163, 63.7448974 ,
#        64.52519165, 54.21749577, 60.98597439, 69.89953274, 68.11389716,
#        63.11714248, 70.12983151, 61.15524617, 56.69543992, 69.59753508,
# ...

# %%
plt.hist(weights)
# Out:
# (array([ 4.,  9., 10., 44., 44., 51., 60., 39., 12.,  7.]),
#  array([49.54814793, 52.35411979, 55.16009165, 57.9660635 , 60.77203536,
#         63.57800722, 66.38397907, 69.18995093, 71.99592279, 74.80189465,
#         77.6078665 ]),
#  <BarContainer object of 10 artists>)
